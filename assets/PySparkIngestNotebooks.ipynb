# %%
##The following file is in this repo make sure its visible in git for the following url
sc.addPyFile('https://raw.githubusercontent.com/Insight-Services-APAC/APAC-Capability-DAI-DbtFabricSparkNb/dev/fabricnotebookutil.py?token=GHSAT0AAAAAACMUPKPEN7Z4ZDXPW62LQAFQZSOZYOA')
from fabricnotebookutil import *
# Out:
# StatementMeta(, 7516b9c8-2aaa-4402-9529-07521a1abf6a, 4, Finished, Available)

# %%
##The following will create notebooks from one lake.Ensure the notebooks do not exist already. 
Utils.import_notebooks(f"/lakehouse/default/Files/", 'd512b955-0371-49e6-a167-36cc6a282874')
# Out:
# StatementMeta(, 7516b9c8-2aaa-4402-9529-07521a1abf6a, 5, Finished, Available)
# Importing individual resources of type 'notebooks' into Fabric workspace 'd512b955-0371-49e6-a167-36cc6a282874'...
# Importing 'master_notebook'...
# >> Notebook 'master_notebook' created.
# Importing 'master_notebook_0'...
# >> Notebook 'master_notebook_0' created.
# Importing 'master_notebook_1'...
# >> Notebook 'master_notebook_1' created.
# Importing 'master_notebook_2'...
# >> Notebook 'master_notebook_2' created.
# Importing 'model.testproj.my_first_dbt_model'...
# >> Notebook 'model.testproj.my_first_dbt_model' created.
# Importing 'model.testproj.my_second_dbt_model'...
# >> Notebook 'model.testproj.my_second_dbt_model' created.
# Importing 'seed.testproj.sample'...
# >> Notebook 'seed.testproj.sample' created.
# Importing 'test.testproj.not_null_my_first_dbt_model_id.5fb22c2710'...
# >> Notebook 'test.testproj.not_null_my_first_dbt_model_id.5fb22c2710' created.
# ...
